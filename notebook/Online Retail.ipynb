# %%
import pandas as pd
import numpy as np

# %%
# Load data
df = pd.read_csv("Online_Retail.csv")

# %%
# Display first few rows of the dataset
print("Initial Shape:", df.shape)
print(df.head())
# Out:
# Initial Shape: (541909, 8)
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4  2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
# Display dataset info
print("\nDataset Info")
print(df.info())
# Out:
# Dataset Info
# <class 'pandas.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  str
#  1   StockCode    541909 non-null  str
#  2   Description  540455 non-null  str
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  str
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  str
# dtypes: float64(2), int64(1), str(5)
# memory usage: 33.1 MB
# None

# %%
#Display missing values
print("\nMissing Values")
print(df.isnull().sum())
# Out:
# Missing Values
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
#Display duplicate rows
print("\nDuplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 5268

# %%
# Remove duplicates
df = df.drop_duplicates()

# %%
# remove invalid sales
df = df[df["Quantity"] > 0]
df = df[df["UnitPrice"] > 0]

# %%
#Add Year and Month columns
df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"])
df["Year"] = df["InvoiceDate"].dt.year
df["Month"] = df["InvoiceDate"].dt.month

# %%
#Drop InvoiceDate column
df = df.drop(columns=["InvoiceDate"])

# %%
#Add revenue column
df["Revenue"] = df["Quantity"] * df["UnitPrice"]

# %%
df = df[
    [
        "InvoiceNo",
        "CustomerID",
        "Country",
        "StockCode",
        "Description",
        "Quantity",
        "UnitPrice",
        "Revenue",
        "Year",
        "Month",
    ]
]

# %%
# Check cleaned data
print("\nCleaned Shape:", df.shape)
print(df.head())
# Out:
# Cleaned Shape: (524878, 10)
#   InvoiceNo  CustomerID         Country StockCode  \
# 0    536365     17850.0  United Kingdom    85123A
# 1    536365     17850.0  United Kingdom     71053
# 2    536365     17850.0  United Kingdom    84406B
# 3    536365     17850.0  United Kingdom    84029G
# 4    536365     17850.0  United Kingdom    84029E
#
#                            Description  Quantity  UnitPrice  Revenue  Year  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6       2.55    15.30  2010
# 1                  WHITE METAL LANTERN         6       3.39    20.34  2010
# 2       CREAM CUPID HEARTS COAT HANGER         8       2.75    22.00  2010
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6       3.39    20.34  2010
# 4       RED WOOLLY HOTTIE WHITE HEART.         6       3.39    20.34  2010
#
#    Month
# 0     12
# 1     12
# 2     12
# 3     12
# 4     12

# %%
df.to_csv("Online_Retail_Cleaned.csv", index=False)

# %%
print('\nDONE! Cleaned data saved to "Online_Retail_Cleaned.csv"')
# Out:
# DONE! Cleaned data saved to "Online_Retail_Cleaned.csv"
